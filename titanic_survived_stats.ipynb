# %%
import pandas as pd
import numpy as np
data = pd.read_csv(r'E:\Data Science & AI\Titanic dataset analysis\DATASET\train.csv')

# %%
data.iloc[7]
# Out:
# PassengerId                                 8
# Survived                                    0
# Pclass                                      3
# Name           Palsson, Master. Gosta Leonard
# Sex                                      male
# Age                                       2.0
# SibSp                                       3
# Parch                                       1
# Ticket                                 349909
# Fare                                   21.075
# Cabin                                     NaN
# Embarked                                    S
# Name: 7, dtype: object

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
del data["Ticket"]

# %%
del data["Name"]

# %%
data
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare Cabin  \
# 0              1         0       3    male  22.0      1      0   7.2500   NaN
# 1              2         1       1  female  38.0      1      0  71.2833   C85
# 2              3         1       3  female  26.0      0      0   7.9250   NaN
# 3              4         1       1  female  35.0      1      0  53.1000  C123
# 4              5         0       3    male  35.0      0      0   8.0500   NaN
# ..           ...       ...     ...     ...   ...    ...    ...      ...   ...
# 886          887         0       2    male  27.0      0      0  13.0000   NaN
# 887          888         1       1  female  19.0      0      0  30.0000   B42
# 888          889         0       3  female   NaN      1      2  23.4500   NaN
# 889          890         1       1    male  26.0      0      0  30.0000  C148
# 890          891         0       3    male  32.0      0      0   7.7500   NaN
#
#     Embarked
# 0          S
# ...

# %%
from sklearn.preprocessing import LabelEncoder
data["Sex"]
labelencoder = LabelEncoder()
data["Sex"] = labelencoder.fit_transform(data["Sex"])
data
# Out:
#      PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch     Fare Cabin  \
# 0              1         0       3    1  22.0      1      0   7.2500   NaN
# 1              2         1       1    0  38.0      1      0  71.2833   C85
# 2              3         1       3    0  26.0      0      0   7.9250   NaN
# 3              4         1       1    0  35.0      1      0  53.1000  C123
# 4              5         0       3    1  35.0      0      0   8.0500   NaN
# ..           ...       ...     ...  ...   ...    ...    ...      ...   ...
# 886          887         0       2    1  27.0      0      0  13.0000   NaN
# 887          888         1       1    0  19.0      0      0  30.0000   B42
# 888          889         0       3    0   NaN      1      2  23.4500   NaN
# 889          890         1       1    1  26.0      0      0  30.0000  C148
# 890          891         0       3    1  32.0      0      0   7.7500   NaN
#
#     Embarked
# 0          S
# 1          C
# 2          S
# ...

# %%
from sklearn.impute import SimpleImputer
simpleimputer = SimpleImputer()
simpleimputer = simpleimputer.fit(data.iloc[:,4:5])
data.iloc[:,4:5] = simpleimputer.transform(data.iloc[:,4:5])

# %%
Sclass = data[(data.Embarked == 'S') & (data.Survived == 0)]
Cclass = data[(data.Embarked == 'C') & (data.Survived == 0)]
Qclass = data[(data.Embarked == 'Q') & (data.Survived == 0)]
Sclass
# Out:
#      PassengerId  Survived  Pclass  Sex        Age  SibSp  Parch     Fare  \
# 0              1         0       3    1  22.000000      1      0   7.2500
# 4              5         0       3    1  35.000000      0      0   8.0500
# 6              7         0       1    1  54.000000      0      0  51.8625
# 7              8         0       3    1   2.000000      3      1  21.0750
# 12            13         0       3    1  20.000000      0      0   8.0500
# ..           ...       ...     ...  ...        ...    ...    ...      ...
# 882          883         0       3    0  22.000000      0      0  10.5167
# 883          884         0       2    1  28.000000      0      0  10.5000
# 884          885         0       3    1  25.000000      0      0   7.0500
# 886          887         0       2    1  27.000000      0      0  13.0000
# 888          889         0       3    0  29.699118      1      2  23.4500
#
#     Cabin Embarked
# 0     NaN        S
# 4     NaN        S
# ...

# %%
Cclass
# Out:
#      PassengerId  Survived  Pclass  Sex        Age  SibSp  Parch     Fare  \
# 26            27         0       3    1  29.699118      0      0   7.2250
# 30            31         0       1    1  40.000000      0      0  27.7208
# 34            35         0       1    1  28.000000      1      0  82.1708
# 42            43         0       3    1  29.699118      0      0   7.8958
# 48            49         0       3    1  29.699118      2      0  21.6792
# ..           ...       ...     ...  ...        ...    ...    ...      ...
# 832          833         0       3    1  29.699118      0      0   7.2292
# 843          844         0       3    1  34.500000      0      0   6.4375
# 847          848         0       3    1  35.000000      0      0   7.8958
# 852          853         0       3    0   9.000000      1      1  15.2458
# 859          860         0       3    1  29.699118      0      0   7.2292
#
#     Cabin Embarked
# 26    NaN        C
# 30    NaN        C
# ...

# %%
Qclass
# Out:
#      PassengerId  Survived  Pclass  Sex        Age  SibSp  Parch     Fare  \
# 5              6         0       3    1  29.699118      0      0   8.4583
# 16            17         0       3    1   2.000000      4      1  29.1250
# 46            47         0       3    1  29.699118      1      0  15.5000
# 116          117         0       3    1  70.500000      0      0   7.7500
# 126          127         0       3    1  29.699118      0      0   7.7500
# 143          144         0       3    1  19.000000      0      0   6.7500
# 171          172         0       3    1   4.000000      4      1  29.1250
# 188          189         0       3    1  40.000000      1      1  15.5000
# 196          197         0       3    1  29.699118      0      0   7.7500
# 214          215         0       3    1  29.699118      1      0   7.7500
# 245          246         0       1    1  44.000000      2      0  90.0000
# 260          261         0       3    1  29.699118      0      0   7.7500
# ...

# %%
data['Embarked'] = labelencoder.fit_transform(data['Embarked'] )
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Fare             0
# Cabin          687
# Embarked         0
# dtype: int64

# %%
import matplotlib.pyplot as plt
from matplotlib import style
del data['Cabin']

# %%
males = (data['Sex'] == 1).sum()
females = (data['Sex'] == 0).sum()
p = [males,females]
plt.pie(p,
        labels = ['Male', 'Female'],
        colors = ['Green','Yellow'],
        explode = (0.15, 0),
        startangle = 0)
plt.axis('equal')
plt.show()

# %%
data
# Out:
#      PassengerId  Survived  Pclass  Sex        Age  SibSp  Parch     Fare  \
# 0              1         0       3    1  22.000000      1      0   7.2500
# 1              2         1       1    0  38.000000      1      0  71.2833
# 2              3         1       3    0  26.000000      0      0   7.9250
# 3              4         1       1    0  35.000000      1      0  53.1000
# 4              5         0       3    1  35.000000      0      0   8.0500
# ..           ...       ...     ...  ...        ...    ...    ...      ...
# 886          887         0       2    1  27.000000      0      0  13.0000
# 887          888         1       1    0  19.000000      0      0  30.0000
# 888          889         0       3    0  29.699118      1      2  23.4500
# 889          890         1       1    1  26.000000      0      0  30.0000
# 890          891         0       3    1  32.000000      0      0   7.7500
#
#      Embarked
# 0           2
# 1           0
# 2           2
# 3           2
# ...

# %%
data.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Fare           0
# Embarked       0
# dtype: int64
